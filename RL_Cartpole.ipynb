# %%
# Import dependencies
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-1.6.0-py3-none-any.whl (177 kB)
# Requirement already satisfied: cloudpickle in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
# Collecting torch>=1.11
#   Downloading torch-1.12.1-cp39-cp39-win_amd64.whl (161.8 MB)
# Requirement already satisfied: pandas in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.3.4)
# Requirement already satisfied: numpy in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.20.3)
# Requirement already satisfied: matplotlib in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.4.3)
# Requirement already satisfied: pillow in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (8.4.0)
# Requirement already satisfied: psutil in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Collecting ale-py==0.7.4
#   Downloading ale_py-0.7.4-cp39-cp39-win_amd64.whl (904 kB)
# Requirement already satisfied: opencv-python in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.9.1)
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: protobuf~=3.19.0 in c:\users\eraym\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.19.4)
# Collecting importlib-metadata>=4.10.0
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: tqdm in c:\users\eraym\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (4.62.3)
# Requirement already satisfied: requests in c:\users\eraym\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.26.0)
# Requirement already satisfied: click in c:\users\eraym\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.3)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.4.2.tar.gz (9.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: zipp>=0.5 in c:\users\eraym\anaconda3\lib\site-packages (from importlib-metadata>=4.10.0->ale-py==0.7.4->stable-baselines3[extra]) (3.6.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.47.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (58.0.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.10.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\eraym\anaconda3\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\eraym\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\eraym\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\eraym\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\eraym\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\eraym\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\eraym\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\eraym\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eraym\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\eraym\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\eraym\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\eraym\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: typing-extensions in c:\users\eraym\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.10.0.2)
# Requirement already satisfied: colorama in c:\users\eraym\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\eraym\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\eraym\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eraym\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eraym\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\eraym\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)
# Building wheels for collected packages: gym, AutoROM.accept-rom-license
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616823 sha256=51a06fee14ddd6063338cd241216a6a24f5ddc9d2188a8a1a779a4b80610ef34
#   Stored in directory: c:\users\eraym\appdata\local\pip\cache\wheels\b3\50\6c\0a82c1358b4da2dbd9c1bb17e0f89467db32812ab236dbf6d5
#   Building wheel for AutoROM.accept-rom-license (PEP 517): started
#   Building wheel for AutoROM.accept-rom-license (PEP 517): finished with status 'done'
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.4.2-py3-none-any.whl size=446447 sha256=8b927642de3c9bcae4445268e76effd738a0b1d60f31b9288b5dd02d2a42d6d9
#   Stored in directory: c:\users\eraym\appdata\local\pip\cache\wheels\2b\03\e4\8b662e95b85786a03898fca125d5a9e3fe49337b1eba8fddd2
# Successfully built gym AutoROM.accept-rom-license
# Installing collected packages: importlib-metadata, torch, importlib-resources, gym, AutoROM.accept-rom-license, autorom, stable-baselines3, ale-py
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.8.1
#     Uninstalling importlib-metadata-4.8.1:
#       Successfully uninstalled importlib-metadata-4.8.1
# Successfully installed AutoROM.accept-rom-license-0.4.2 ale-py-0.7.4 autorom-0.4.2 gym-0.21.0 importlib-metadata-4.12.0 importlib-resources-5.9.0 stable-baselines3-1.6.0 torch-1.12.1

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Load Environment
environment_name = "CartPole-v0"

env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:65.0
# Episode:2 Score:46.0
# Episode:3 Score:45.0
# Episode:4 Score:27.0
# Episode:5 Score:48.0

# %%
# Understanding The Environment
env.action_space.sample()
# 0-push cart to left, 1-push cart to the right
# Out:
# 1

# %%
env.observation_space.sample()
# [cart position, cart velocity, pole angle, pole angular velocity]
# Out:
# array([ 3.9290626e+00, -9.1089731e+37, -3.1479254e-02, -1.1330018e+38],
#       dtype=float32)

# %%
# Train an RL Model
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1217 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008730016 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00319    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.79        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 48.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009265802 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 33.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008253658 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008278734 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 61.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 662         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009076448 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 59.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 658         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006833584 |
# |    clip_fraction        | 0.0611      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 654         |
# |    iterations           | 8           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004910434 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.566      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 41.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 9           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006661281 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 28.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 10           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0032897224 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.559       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.26         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 13.5         |
# ------------------------------------------

# %%
# Save and Reload Model
import os
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_model')

# %%
model.save(PPO_path)
# Out:
# C:\Users\eraym\anaconda3\lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'Training\Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
del model

# %%
model = PPO.load('Training/Saved Models/PPO_model', env=env)

# %%
# Evaluation
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\eraym\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %%
# Test Model
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([-0.03061121, -0.41353926,  0.05644975,  0.06191196], dtype=float32)}]

# %%
env.close()

# %%
# Viewing Logs in Tensorboard
training_log_path = os.path.join(log_path, 'PPO_3')

# %%
# Adding a callback to the training Stage
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 386  |
# |    iterations      | 1    |
# |    time_elapsed    | 5    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008157235 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.0104     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.28        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 55.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 522        |
# |    iterations           | 3          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00884589 |
# |    clip_fraction        | 0.0552     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.667     |
# |    explained_variance   | 0.0695     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.6       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 35.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009310743 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 54.6        |
# -----------------------------------------
# C:\Users\eraym\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=197.40 +/- 5.20
# Episode length: 197.40 +/- 5.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 197         |
# |    mean_reward          | 197         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.006334926 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 62.1        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 197.40  is above the threshold 190

# %%
model_path = os.path.join('Training', 'Saved Models', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (199.1, 2.7)

# %%
env.close()

# %%
# Changing Policies
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 470  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 323         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014374632 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.000391    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016028874 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0338     |
# |    value_loss           | 25          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 305        |
# |    iterations           | 4          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01230335 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.437      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.4       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.
|
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 2256     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 2260     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 2266     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 2266     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 2269     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 2269     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 2269     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 2268     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 2273     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 2275     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 2279     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 2281     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 2281     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 2284     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 2285     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 2287     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 2288     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 2291     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12235    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 2294     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 2296     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12415    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 2298     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 2302     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 2302     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 2308     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 2307     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 2314     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12901    |
# ----------------------------------
# ...
# |    fps              | 2340     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 2342     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 2337     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 2338     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 2348     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 2345     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 2345     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 2345     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 2345     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 2347     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16501    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 2349     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 2353     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 2350     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 2351     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 2351     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 2361     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 2358     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 2358     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 2361     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 2361     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 2365     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 2370     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 2374     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 2378     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 2380     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 2382     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 2386     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 2386     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 2388     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 2390     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 2389     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18354    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 2387     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 2364     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 2367     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 2365     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 2366     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18757    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 2367     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 2369     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18905    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 2369     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 18961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 2371     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 2350     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 2355     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 2357     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 2363     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 2362     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 2362     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 2364     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 2366     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 2369     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 2370     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19998    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=9.60 +/- 0.80
# Episode length: 9.60 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (9.7, 0.7810249675906654)

# %%
env.close()
